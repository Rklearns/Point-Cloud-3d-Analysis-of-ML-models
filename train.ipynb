# %%
import os
import numpy as np
import torch
import torch.nn as nn
import torch.nn.functional as F
from torch.utils.data import Dataset, DataLoader

class PropellerDataset(Dataset):
    def __init__(self, root='data'):
        self.points = np.load(os.path.join(root, 'points.npy')).astype(np.float32)
        self.labels = np.load(os.path.join(root, 'labels.npy')).astype(np.int64)

    def __len__(self):
        return 1

    def __getitem__(self, idx):
        return self.points, self.labels

# %%
def knn(x, k):
    inner = -2 * torch.matmul(x.transpose(2, 1), x)
    xx = torch.sum(x ** 2, dim=1, keepdim=True)
    pairwise_distance = -xx - inner - xx.transpose(2, 1)
    idx = pairwise_distance.topk(k=k, dim=-1)[1]
    return idx

def get_graph_feature(x, k=20, idx=None):
    batch_size, num_dims, num_points = x.size()
    k = min(k, num_points - 1)
    if idx is None:
        idx = knn(x, k=k)
    device = x.device
    idx_base = torch.arange(0, batch_size, device=device).view(-1, 1, 1) * num_points
    idx = idx + idx_base
    idx = idx.view(-1)
    x = x.transpose(2, 1).contiguous()
    feature = x.view(batch_size * num_points, -1)[idx, :]
    feature = feature.view(batch_size, num_points, k, num_dims)
    x = x.view(batch_size, num_points, 1, num_dims).repeat(1, 1, k, 1)
    feature = torch.cat((feature - x, x), dim=3).permute(0, 3, 1, 2).contiguous()
    return feature

# %%
class DGCNN(nn.Module):
    def __init__(self, args, output_channels=4):
        super(DGCNN, self).__init__()
        self.k = args.k
        self.bn1 = nn.BatchNorm2d(64)
        self.bn2 = nn.BatchNorm2d(64)
        self.bn3 = nn.BatchNorm2d(128)
        self.bn4 = nn.BatchNorm2d(256)
        self.bn5 = nn.BatchNorm1d(args.emb_dims)

        self.conv1 = nn.Sequential(nn.Conv2d(6, 64, 1, bias=False), self.bn1, nn.LeakyReLU(0.2))
        self.conv2 = nn.Sequential(nn.Conv2d(128, 64, 1, bias=False), self.bn2, nn.LeakyReLU(0.2))
        self.conv3 = nn.Sequential(nn.Conv2d(128, 128, 1, bias=False), self.bn3, nn.LeakyReLU(0.2))
        self.conv4 = nn.Sequential(nn.Conv2d(256, 256, 1, bias=False), self.bn4, nn.LeakyReLU(0.2))
        self.conv5 = nn.Sequential(nn.Conv1d(512, args.emb_dims, 1, bias=False), self.bn5, nn.LeakyReLU(0.2))
        self.dp1 = nn.Dropout(p=args.dropout)
        self.conv_seg = nn.Conv1d(args.emb_dims, output_channels, 1)

    def forward(self, x):
        batch_size, _, num_points = x.size()
        x1 = self.conv1(get_graph_feature(x, k=self.k)).max(dim=-1)[0]
        x2 = self.conv2(get_graph_feature(x1, k=self.k)).max(dim=-1)[0]
        x3 = self.conv3(get_graph_feature(x2, k=self.k)).max(dim=-1)[0]
        x4 = self.conv4(get_graph_feature(x3, k=self.k)).max(dim=-1)[0]
        x_cat = torch.cat((x1, x2, x3, x4), dim=1)
        x = self.conv5(x_cat)
        x = self.dp1(x)
        x = self.conv_seg(x)
        return x.transpose(2, 1).contiguous()

# %%
class Args:
    def __init__(self):
        self.k = 20
        self.emb_dims = 1024
        self.dropout = 0.5

args = Args()
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

model = DGCNN(args, output_channels=4).to(device)
optimizer = torch.optim.Adam(model.parameters(), lr=0.001)
criterion = nn.CrossEntropyLoss()

dataset = PropellerDataset()
loader = DataLoader(dataset, batch_size=1, shuffle=False)

# %%
from collections import defaultdict

for epoch in range(20):
    model.train()
    total_loss = 0.0
    correct = total = 0

    # Initialize per-class stats
    correct_per_class = defaultdict(int)
    total_per_class = defaultdict(int)

    for points, labels in loader:
        points = points.to(device)        # [1, N, 3]
        labels = labels.to(device)        # [1, N]
        points = points.permute(0, 2, 1)  # [1, 3, N]

        outputs = model(points)           # [1, N, 4]
        loss = criterion(outputs.view(-1, 4), labels.view(-1))

        optimizer.zero_grad()
        loss.backward()
        optimizer.step()

        total_loss += loss.item()

        preds = outputs.argmax(dim=2)  # [1, N]
        correct += (preds == labels).sum().item()
        total += labels.numel()

        # Count per-class stats
        for p, l in zip(preds.view(-1), labels.view(-1)):
            total_per_class[l.item()] += 1
            if p.item() == l.item():
                correct_per_class[l.item()] += 1

    acc = 100 * correct / total
    print(f"\n📉 Epoch {epoch+1}, Loss: {total_loss:.4f}, ✅ Accuracy: {acc:.2f}%")

    # Per-class accuracy
    for cls in sorted(total_per_class.keys()):
        class_acc = 100 * correct_per_class[cls] / total_per_class[cls]
        print(f"  🔹 Class {cls}: {class_acc:.2f}% accuracy ({correct_per_class[cls]}/{total_per_class[cls]})")
# Out:
# 📉 Epoch 1, Loss: 0.0050, ✅ Accuracy: 99.85%
#   🔹 Class 0: 99.14% accuracy (346/349)
#   🔹 Class 1: 100.00% accuracy (837/837)
#   🔹 Class 3: 100.00% accuracy (856/856)
#
# 📉 Epoch 2, Loss: 0.0056, ✅ Accuracy: 99.80%
#   🔹 Class 0: 99.43% accuracy (347/349)
#   🔹 Class 1: 100.00% accuracy (837/837)
#   🔹 Class 3: 99.77% accuracy (854/856)
#
# 📉 Epoch 3, Loss: 0.0044, ✅ Accuracy: 99.90%
#   🔹 Class 0: 99.43% accuracy (347/349)
#   🔹 Class 1: 100.00% accuracy (837/837)
#   🔹 Class 3: 100.00% accuracy (856/856)
#
# 📉 Epoch 4, Loss: 0.0038, ✅ Accuracy: 99.90%
#   🔹 Class 0: 99.43% accuracy (347/349)
#   🔹 Class 1: 100.00% accuracy (837/837)
#   🔹 Class 3: 100.00% accuracy (856/856)
#
# 📉 Epoch 5, Loss: 0.0037, ✅ Accuracy: 99.90%
#   🔹 Class 0: 99.43% accuracy (347/349)
#   🔹 Class 1: 100.00% accuracy (837/837)
#   🔹 Class 3: 100.00% accuracy (856/856)
#
# 📉 Epoch 6, Loss: 0.0029, ✅ Accuracy: 100.00%
#   🔹 Class 0: 100.00% accuracy (349/349)
#   🔹 Class 1: 100.00% accuracy (837/837)
#   🔹 Class 3: 100.00% accuracy (856/856)
#
# 📉 Epoch 7, Loss: 0.0027, ✅ Accuracy: 99.95%
#   🔹 Class 0: 99.71% accuracy (348/349)
#   🔹 Class 1: 100.00% accuracy (837/837)
#   🔹 Class 3: 100.00% accuracy (856/856)
#
# 📉 Epoch 8, Loss: 0.0023, ✅ Accuracy: 100.00%
#   🔹 Class 0: 100.00% accuracy (349/349)
#   🔹 Class 1: 100.00% accuracy (837/837)
#   🔹 Class 3: 100.00% accuracy (856/856)
#
# 📉 Epoch 9, Loss: 0.0022, ✅ Accuracy: 99.95%
#   🔹 Class 0: 100.00% accuracy (349/349)
#   🔹 Class 1: 100.00% accuracy (837/837)
#   🔹 Class 3: 99.88% accuracy (855/856)
#
# 📉 Epoch 10, Loss: 0.0017, ✅ Accuracy: 100.00%
#   🔹 Class 0: 100.00% accuracy (349/349)
#   🔹 Class 1: 100.00% accuracy (837/837)
#   🔹 Class 3: 100.00% accuracy (856/856)
#
# 📉 Epoch 11, Loss: 0.0021, ✅ Accuracy: 100.00%
#   🔹 Class 0: 100.00% accuracy (349/349)
#   🔹 Class 1: 100.00% accuracy (837/837)
#   🔹 Class 3: 100.00% accuracy (856/856)
#
# 📉 Epoch 12, Loss: 0.0021, ✅ Accuracy: 99.95%
#   🔹 Class 0: 100.00% accuracy (349/349)
#   🔹 Class 1: 100.00% accuracy (837/837)
#   🔹 Class 3: 99.88% accuracy (855/856)
#
# 📉 Epoch 13, Loss: 0.0015, ✅ Accuracy: 100.00%
#   🔹 Class 0: 100.00% accuracy (349/349)
#   🔹 Class 1: 100.00% accuracy (837/837)
#   🔹 Class 3: 100.00% accuracy (856/856)
#
# 📉 Epoch 14, Loss: 0.0013, ✅ Accuracy: 100.00%
#   🔹 Class 0: 100.00% accuracy (349/349)
#   🔹 Class 1: 100.00% accuracy (837/837)
#   🔹 Class 3: 100.00% accuracy (856/856)
#
# 📉 Epoch 15, Loss: 0.0012, ✅ Accuracy: 100.00%
#   🔹 Class 0: 100.00% accuracy (349/349)
#   🔹 Class 1: 100.00% accuracy (837/837)
#   🔹 Class 3: 100.00% accuracy (856/856)
#
# 📉 Epoch 16, Loss: 0.0012, ✅ Accuracy: 100.00%
#   🔹 Class 0: 100.00% accuracy (349/349)
#   🔹 Class 1: 100.00% accuracy (837/837)
#   🔹 Class 3: 100.00% accuracy (856/856)
#
# 📉 Epoch 17, Loss: 0.0009, ✅ Accuracy: 100.00%
#   🔹 Class 0: 100.00% accuracy (349/349)
#   🔹 Class 1: 100.00% accuracy (837/837)
#   🔹 Class 3: 100.00% accuracy (856/856)
#
# 📉 Epoch 18, Loss: 0.0008, ✅ Accuracy: 100.00%
#   🔹 Class 0: 100.00% accuracy (349/349)
#   🔹 Class 1: 100.00% accuracy (837/837)
#   🔹 Class 3: 100.00% accuracy (856/856)
#
# 📉 Epoch 19, Loss: 0.0009, ✅ Accuracy: 100.00%
#   🔹 Class 0: 100.00% accuracy (349/349)
#   🔹 Class 1: 100.00% accuracy (837/837)
#   🔹 Class 3: 100.00% accuracy (856/856)
#
# 📉 Epoch 20, Loss: 0.0009, ✅ Accuracy: 100.00%
#   🔹 Class 0: 100.00% accuracy (349/349)
#   🔹 Class 1: 100.00% accuracy (837/837)
#   🔹 Class 3: 100.00% accuracy (856/856)

# %%
# !pip install open3d
import open3d as o3d
import torch
import numpy as np

def mesh_to_pointcloud(filepath, num_points=2048):
    mesh = o3d.io.read_triangle_mesh(filepath)
    mesh.compute_vertex_normals()

    # Sample points uniformly
    pcd = mesh.sample_points_uniformly(number_of_points=num_points)
    points = np.asarray(pcd.points, dtype=np.float32)
    
    # [1, 3, N] format for DGCNN
    points = torch.tensor(points).unsqueeze(0).permute(0, 2, 1)
    return points, pcd  # return pcd if you want to visualize
# Out:
# Requirement already satisfied: open3d in c:\users\rishit\anaconda3\lib\site-packages (0.19.0)
# Requirement already satisfied: numpy>=1.18.0 in c:\users\rishit\anaconda3\lib\site-packages (from open3d) (1.26.4)
# Requirement already satisfied: dash>=2.6.0 in c:\users\rishit\anaconda3\lib\site-packages (from open3d) (3.0.4)
# Requirement already satisfied: werkzeug>=3.0.0 in c:\users\rishit\anaconda3\lib\site-packages (from open3d) (3.0.3)
# Requirement already satisfied: flask>=3.0.0 in c:\users\rishit\anaconda3\lib\site-packages (from open3d) (3.0.3)
# Requirement already satisfied: nbformat>=5.7.0 in c:\users\rishit\anaconda3\lib\site-packages (from open3d) (5.10.4)
# Requirement already satisfied: configargparse in c:\users\rishit\anaconda3\lib\site-packages (from open3d) (1.7.1)
# Requirement already satisfied: ipywidgets>=8.0.4 in c:\users\rishit\anaconda3\lib\site-packages (from open3d) (8.1.7)
# Requirement already satisfied: plotly>=5.0.0 in c:\users\rishit\anaconda3\lib\site-packages (from dash>=2.6.0->open3d) (5.24.1)
# Requirement already satisfied: importlib-metadata in c:\users\rishit\anaconda3\lib\site-packages (from dash>=2.6.0->open3d) (7.0.1)
# Requirement already satisfied: typing-extensions>=4.1.1 in c:\users\rishit\anaconda3\lib\site-packages (from dash>=2.6.0->open3d) (4.11.0)
# Requirement already satisfied: requests in c:\users\rishit\anaconda3\lib\site-packages (from dash>=2.6.0->open3d) (2.32.3)
# Requirement already satisfied: retrying in c:\users\rishit\anaconda3\lib\site-packages (from dash>=2.6.0->open3d) (1.3.4)
# Requirement already satisfied: nest-asyncio in c:\users\rishit\anaconda3\lib\site-packages (from dash>=2.6.0->open3d) (1.6.0)
# Requirement already satisfied: setuptools in c:\users\rishit\anaconda3\lib\site-packages (from dash>=2.6.0->open3d) (75.1.0)
# Requirement already satisfied: Jinja2>=3.1.2 in c:\users\rishit\anaconda3\lib\site-packages (from flask>=3.0.0->open3d) (3.1.4)
# Requirement already satisfied: itsdangerous>=2.1.2 in c:\users\rishit\anaconda3\lib\site-packages (from flask>=3.0.0->open3d) (2.2.0)
# Requirement already satisfied: click>=8.1.3 in c:\users\rishit\anaconda3\lib\site-packages (from flask>=3.0.0->open3d) (8.1.7)
# Requirement already satisfied: blinker>=1.6.2 in c:\users\rishit\anaconda3\lib\site-packages (from flask>=3.0.0->open3d) (1.6.2)
# Requirement already satisfied: comm>=0.1.3 in c:\users\rishit\anaconda3\lib\site-packages (from ipywidgets>=8.0.4->open3d) (0.2.1)
# Requirement already satisfied: ipython>=6.1.0 in c:\users\rishit\anaconda3\lib\site-packages (from ipywidgets>=8.0.4->open3d) (8.27.0)
# Requirement already satisfied: traitlets>=4.3.1 in c:\users\rishit\anaconda3\lib\site-packages (from ipywidgets>=8.0.4->open3d) (5.14.3)
# Requirement already satisfied: widgetsnbextension~=4.0.14 in c:\users\rishit\anaconda3\lib\site-packages (from ipywidgets>=8.0.4->open3d) (4.0.14)
# Requirement already satisfied: jupyterlab_widgets~=3.0.15 in c:\users\rishit\anaconda3\lib\site-packages (from ipywidgets>=8.0.4->open3d) (3.0.15)
# Requirement already satisfied: fastjsonschema>=2.15 in c:\users\rishit\anaconda3\lib\site-packages (from nbformat>=5.7.0->open3d) (2.16.2)
# Requirement already satisfied: jsonschema>=2.6 in c:\users\rishit\anaconda3\lib\site-packages (from nbformat>=5.7.0->open3d) (4.23.0)
# Requirement already satisfied: jupyter-core!=5.0.*,>=4.12 in c:\users\rishit\anaconda3\lib\site-packages (from nbformat>=5.7.0->open3d) (5.7.2)
# Requirement already satisfied: MarkupSafe>=2.1.1 in c:\users\rishit\anaconda3\lib\site-packages (from werkzeug>=3.0.0->open3d) (2.1.3)
# Requirement already satisfied: colorama in c:\users\rishit\anaconda3\lib\site-packages (from click>=8.1.3->flask>=3.0.0->open3d) (0.4.6)
# Requirement already satisfied: decorator in c:\users\rishit\anaconda3\lib\site-packages (from ipython>=6.1.0->ipywidgets>=8.0.4->open3d) (5.1.1)
# Requirement already satisfied: jedi>=0.16 in c:\users\rishit\anaconda3\lib\site-packages (from ipython>=6.1.0->ipywidgets>=8.0.4->open3d) (0.19.1)
# Requirement already satisfied: matplotlib-inline in c:\users\rishit\anaconda3\lib\site-packages (from ipython>=6.1.0->ipywidgets>=8.0.4->open3d) (0.1.6)
# Requirement already satisfied: prompt-toolkit<3.1.0,>=3.0.41 in c:\users\rishit\anaconda3\lib\site-packages (from ipython>=6.1.0->ipywidgets>=8.0.4->open3d) (3.0.43)
# Requirement already satisfied: pygments>=2.4.0 in c:\users\rishit\anaconda3\lib\site-packages (from ipython>=6.1.0->ipywidgets>=8.0.4->open3d) (2.15.1)
# Requirement already satisfied: stack-data in c:\users\rishit\anaconda3\lib\site-packages (from ipython>=6.1.0->ipywidgets>=8.0.4->open3d) (0.2.0)
# Requirement already satisfied: attrs>=22.2.0 in c:\users\rishit\anaconda3\lib\site-packages (from jsonschema>=2.6->nbformat>=5.7.0->open3d) (23.1.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in c:\users\rishit\anaconda3\lib\site-packages (from jsonschema>=2.6->nbformat>=5.7.0->open3d) (2023.7.1)
# Requirement already satisfied: referencing>=0.28.4 in c:\users\rishit\anaconda3\lib\site-packages (from jsonschema>=2.6->nbformat>=5.7.0->open3d) (0.30.2)
# Requirement already satisfied: rpds-py>=0.7.1 in c:\users\rishit\anaconda3\lib\site-packages (from jsonschema>=2.6->nbformat>=5.7.0->open3d) (0.10.6)
# Requirement already satisfied: platformdirs>=2.5 in c:\users\rishit\anaconda3\lib\site-packages (from jupyter-core!=5.0.*,>=4.12->nbformat>=5.7.0->open3d) (3.10.0)
# Requirement already satisfied: pywin32>=300 in c:\users\rishit\anaconda3\lib\site-packages (from jupyter-core!=5.0.*,>=4.12->nbformat>=5.7.0->open3d) (305.1)
# Requirement already satisfied: tenacity>=6.2.0 in c:\users\rishit\anaconda3\lib\site-packages (from plotly>=5.0.0->dash>=2.6.0->open3d) (8.2.3)
# Requirement already satisfied: packaging in c:\users\rishit\anaconda3\lib\site-packages (from plotly>=5.0.0->dash>=2.6.0->open3d) (24.1)
# Requirement already satisfied: zipp>=0.5 in c:\users\rishit\anaconda3\lib\site-packages (from importlib-metadata->dash>=2.6.0->open3d) (3.17.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\rishit\anaconda3\lib\site-packages (from requests->dash>=2.6.0->open3d) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\rishit\anaconda3\lib\site-packages (from requests->dash>=2.6.0->open3d) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\rishit\anaconda3\lib\site-packages (from requests->dash>=2.6.0->open3d) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\rishit\anaconda3\lib\site-packages (from requests->dash>=2.6.0->open3d) (2024.8.30)
# Requirement already satisfied: six>=1.7.0 in c:\users\rishit\anaconda3\lib\site-packages (from retrying->dash>=2.6.0->open3d) (1.16.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.3 in c:\users\rishit\anaconda3\lib\site-packages (from jedi>=0.16->ipython>=6.1.0->ipywidgets>=8.0.4->open3d) (0.8.3)
# Requirement already satisfied: wcwidth in c:\users\rishit\anaconda3\lib\site-packages (from prompt-toolkit<3.1.0,>=3.0.41->ipython>=6.1.0->ipywidgets>=8.0.4->open3d) (0.2.5)
# Requirement already satisfied: executing in c:\users\rishit\anaconda3\lib\site-packages (from stack-data->ipython>=6.1.0->ipywidgets>=8.0.4->open3d) (0.8.3)
# Requirement already satisfied: asttokens in c:\users\rishit\anaconda3\lib\site-packages (from stack-data->ipython>=6.1.0->ipywidgets>=8.0.4->open3d) (2.0.5)
# Requirement already satisfied: pure-eval in c:\users\rishit\anaconda3\lib\site-packages (from stack-data->ipython>=6.1.0->ipywidgets>=8.0.4->open3d) (0.2.2)
# Jupyter environment detected. Enabling Open3D WebVisualizer.
# [Open3D INFO] WebRTC GUI backend enabled.
# [Open3D INFO] WebRTCWindowSystem: HTTP handshake server disabled.

# %%
model.eval()
points_a, _ = mesh_to_pointcloud("10x4M-LH-PERF.STL")
points_b, _ = mesh_to_pointcloud("11x6M-LH-PERF (1).STL")
points_c, _ = mesh_to_pointcloud("14x13M.STL")

# %%
with torch.no_grad():
    preds_a = model(points_a).argmax(dim=2).view(-1)
    preds_b = model(points_b).argmax(dim=2).view(-1)
    preds_c = model(points_c).argmax(dim=2).view(-1)

# Compare predictions
def compute_error(pred1, pred2):
    min_len = min(len(pred1), len(pred2))
    return 100.0 * (pred1[:min_len] != pred2[:min_len]).sum().item() / min_len

print(f"🔹 Error A vs B: {compute_error(preds_a, preds_b):.2f}%")
print(f"🔹 Error A vs C: {compute_error(preds_a, preds_c):.2f}%")
# Out:
# 🔹 Error A vs B: 88.28%
# 🔹 Error A vs C: 88.28%
